# %%
from pandas import*
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_obj = pd.read_csv('epldata_final.csv')

# %%
df_obj
# Out:
#                         name         club  age position  position_cat  \
# 0             Alexis Sanchez      Arsenal   28       LW             1
# 1                 Mesut Ozil      Arsenal   28       AM             1
# 2                  Petr Cech      Arsenal   35       GK             4
# 3               Theo Walcott      Arsenal   28       RW             1
# 4          Laurent Koscielny      Arsenal   31       CB             3
# 5            Hector Bellerin      Arsenal   22       RB             3
# 6             Olivier Giroud      Arsenal   30       CF             1
# 7              Nacho Monreal      Arsenal   31       LB             3
# 8           Shkodran Mustafi      Arsenal   25       CB             3
# 9                 Alex Iwobi      Arsenal   21       LW             1
# 10              Granit Xhaka      Arsenal   24       DM             2
# 11   Alex Oxlade-Chamberlain      Arsenal   23       RM             2
# ...

# %%
#most valuable market value
items_counts = df_obj['market_value'].value_counts()
max_item = items_counts.max()

# %%
print(max_item)
# Out:
# 41

# %%
#distribution of market value 
df_obj.hist(column="market_value")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0520c8e5c0>]],
#       dtype=object)

# %%
#market value with age
_=plt.hist(df_obj['market_value'])
_=plt.xlabel('age')
_=plt.ylabel('market_value')
plt.show()

# %%
#The top six
items_counts = df_obj['market_value'].value_counts()
max_item = items_counts.max()

# %%
max_item.head(6)

# %%
#distribution of popularity
df_obj.hist(column="page_views")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f04f906ebe0>]],
#       dtype=object)
